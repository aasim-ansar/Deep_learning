# %%
# Importing the Dependencies

import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# %%
# downloading the dataset

(x_train,y_train), (x_test,y_test) = datasets.cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
# Normalize pixel values (0–255 → 0–1)
X_train = x_train / 255.0
X_test = x_test / 255.0

# %%
# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
# Data augmentation

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

datagen.fit(X_train)

# %%
# cnn model

model = Sequential([
    Input(shape=(32, 32, 3)),    
    
    Conv2D(32, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# %%
# model compile

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# train with augmentation

history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    epochs=20,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 86ms/step - accuracy: 0.2842 - loss: 1.9222 - val_accuracy: 0.5095 - val_loss: 1.3570
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.4859 - loss: 1.4320 - val_accuracy: 0.5997 - val_loss: 1.1162
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.5486 - loss: 1.2721 - val_accuracy: 0.6147 - val_loss: 1.1000
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.5863 - loss: 1.1677 - val_accuracy: 0.6594 - val_loss: 0.9432
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.6126 - loss: 1.1045 - val_accuracy: 0.6539 - val_loss: 0.9911
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.6347 - loss: 1.0503 - val_accuracy: 0.7001 - val_loss: 0.8479
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.6515 - loss: 1.0012 - val_accuracy: 0.7044 - val_loss: 0.8575
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.6703 - loss: 0.9548 - val_accuracy: 0.7212 - val_loss: 0.8022
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.6752 - loss: 0.9467 - val_accuracy: 0.7135 - val_loss: 0.8316
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.6830 - loss: 0.9108 - val_accuracy: 0.7323 - val_loss: 0.7806
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.6928 - loss: 0.8866 - val_accuracy: 0.7478 - val_loss: 0.7239
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.7000 - loss: 0.8729 - val_accuracy: 0.7513 - val_loss: 0.7164
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.7117 - loss: 0.8400 - val_accuracy: 0.7481 - val_loss: 0.7329
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.7138 - loss: 0.8435 - val_accuracy: 0.7397 - val_loss: 0.7617
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.7151 - loss: 0.8161 - val_accuracy: 0.7509 - val_loss: 0.7370
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.7234 - loss: 0.8130 - val_accuracy: 0.7758 - val_loss: 0.6625
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.7323 - loss: 0.7778 - val_accuracy: 0.7522 - val_loss: 0.7250
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 77ms/step - accuracy: 0.7335 - loss: 0.7747 - val_accuracy: 0.7718 - val_loss: 0.6682
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 76ms/step - accuracy: 0.7334 - loss: 0.7743 - val_accuracy: 0.7331 - val_loss: 0.7977
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.7412 - loss: 0.7571 - val_accuracy: 0.7720 - val_loss: 0.6784

# %%
# testing accuracy

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy:.4f}")

# %%
# training accuracy

train_loss, train_accuracy = model.evaluate(X_train, y_train)
print(f"Train Accuracy: {train_accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 # training accuracy
# ----> 3 train_loss, train_accuracy = model.evaluate(X_train, y_train)
#       4 print(f"Train Accuracy: {train_accuracy:.4f}")
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\nn.py:660, in categorical_crossentropy(target, output, from_logits, axis)
#     658 for e1, e2 in zip(target.shape, output.shape):
#     659     if e1 is not None and e2 is not None and e1 != e2:
# --> 660         raise ValueError(
#     661             "Arguments `target` and `output` must have the same shape. "
#     662             "Received: "
#     663             f"target.shape={target.shape}, output.shape={output.shape}"
#     664         )
#     666 output, from_logits = _get_logits(
#     667     output, from_logits, "Softmax", "categorical_crossentropy"
#     668 )
#     669 if from_logits:
#
# ValueError: Arguments `target` and `output` must have the same shape. Received: target.shape=(None, 1), output.shape=(None, 10)
